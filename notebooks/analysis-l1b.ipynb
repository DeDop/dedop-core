# %% [markdown]
# # DeDop L1B Analysis

# %%
from dedop.cli.analysis import L1bAnalysis
# %matplotlib inline

# %%
#an = L1bAnalysis("D:\\EOData\\DeDop\\L1B.nc")
an = L1bAnalysis("C:\\Users\\Norman\\EOData\\DeDop\\S3\\L1B.nc")

# %%
an.plot_im()

# %%
an.time_range
# Out:
# (datetime.datetime(2013, 4, 15, 5, 42, 7, 215659),
#  datetime.datetime(2013, 4, 15, 5, 42, 57, 179189))

# %%
an.lat_range
# Out:
# (3.97925, 6.9323030000000001)

# %%
an.lon_range
# Out:
# (63.214408999999989, 63.872471999999988)

# %%
an.plot_locs()

# %%
an.meas_range
# Out:
# (1205.3677999999998, 30087273.237540003)

# %%
an.plot_meas_im(vmin=0, vmax=7e6)

# %%
an.plot_meas_hist(vmin=0, vmax=1e7, log=True)

# %%
an.plot_meas(ind=500)

# %%
an.plot_meas(ref_ind=500)

# %%
an.plot_2d_var()

# %%
an.dim_names_to_var_names
# Out:
# {('echo_sample_ind',): {'echo_sample_ind'},
#  ('max_multi_stack_ind',): {'max_multi_stack_ind'},
#  ('time_l1b_echo_lrm',): {'GPS_time_l1b_echo_lrm',
#   'UTC_day_l1b_echo_lrm',
#   'UTC_sec_l1b_echo_lrm',
#   'acq_stat_l1b_echo_lrm',
#   'agc_c_l1b_echo_lrm',
#   'agc_cor_c_l1b_echo_lrm',
#   'agc_cor_ku_l1b_echo_lrm',
#   'agc_ku_l1b_echo_lrm',
#   'agccode_c_l1b_echo_lrm',
#   'agccode_ku_l1b_echo_lrm',
#   'alt_l1b_echo_lrm',
#   'cl_gain_l1b_echo_lrm',
#   'cor2_applied_l1b_echo_lrm',
#   'cor2_nav_dem_l1b_echo_lrm',
#   'dem_eeprom_l1b_echo_lrm',
#   'dh0_l1b_echo_lrm',
#   'dop_cor_c_l1b_echo_lrm',
#   'dop_cor_ku_l1b_echo_lrm',
#   'flag_gnss_status_l1b_echo_lrm',
#   'flag_man_plane_l1b_echo_lrm',
#   'flag_man_pres_l1b_echo_lrm',
#   'flag_man_thrust_l1b_echo_lrm',
#   'flag_time_corr_val_l1b_echo_lrm',
#   'flag_time_status_l1b_echo_lrm',
#   'h0_applied_l1b_echo_lrm',
#   'h0_nav_dem_l1b_echo_lrm',
#   'int_path_cor_c_l1b_echo_lrm',
#   'int_path_cor_ku_l1b_echo_lrm',
#   'isp_coarse_time_l1b_echo_lrm',
#   'isp_fine_time_l1b_echo_lrm',
#   'isp_time_status_l1b_echo_lrm',
#   'lat_l1b_echo_lrm',
#   'lon_l1b_echo_lrm',
#   'loss_track_l1b_echo_lrm',
#   'mode_id_l1b_echo_lrm',
#   'nav_bul_coarse_time_l1b_echo_lrm',
#   'nav_bul_fine_time_l1b_echo_lrm',
#   'nav_bul_source_l1b_echo_lrm',
#   'nav_bul_status_l1b_echo_lrm',
#   'oper_instr_l1b_echo_lrm',
#   'orb_alt_rate_l1b_echo_lrm',
#   'range_c_l1b_echo_lrm',
#   'range_ku_l1b_echo_lrm',
#   'range_rate_l1b_echo_lrm',
#   'scale_factor_c_l1b_echo_lrm',
#   'scale_factor_ku_l1b_echo_lrm',
#   'seq_count_l1b_echo_lrm',
#   'sig0_cal_c_l1b_echo_lrm',
#   'sig0_cal_ku_l1b_echo_lrm',
#   'sral_fine_time_l1b_echo_lrm',
#   'surf_type_l1b_echo_lrm',
#   'time_l1b_echo_lrm',
#   'uso_cor_l1b_echo_lrm',
#   'weighting_l1b_echo_lrm',
#   'x_pos_l1b_echo_lrm',
#   'x_vel_l1b_echo_lrm',
#   'y_pos_l1b_echo_lrm',
#   'y_vel_l1b_echo_lrm',
#   'z_pos_l1b_echo_lrm',
#   'z_vel_l1b_echo_lrm'},
#  ('time_l1b_echo_lrm', 'echo_sample_ind'): {'i2q2_meas_c_l1b_echo_lrm',
#   'i2q2_meas_ku_l1b_echo_lrm'},
#  ('time_l1b_echo_plrm',): {'GPS_time_l1b_echo_plrm',
#   'SAR_mode_l1b_echo_plrm',
#   'UTC_day_l1b_echo_plrm',
#   'UTC_sec_l1b_echo_plrm',
#   'acq_stat_l1b_echo_plrm',
#   'agc_c_l1b_echo_plrm',
#   'agc_cor_c_l1b_echo_plrm',
#   'agc_cor_ku_l1b_echo_plrm',
#   'agc_ku_l1b_echo_plrm',
#   'agccode_c_l1b_echo_plrm',
#   'agccode_ku_l1b_echo_plrm',
#   'alt_l1b_echo_plrm',
#   'cl_gain_l1b_echo_plrm',
#   'cor2_applied_l1b_echo_plrm',
#   'cor2_nav_dem_l1b_echo_plrm',
#   'dem_eeprom_l1b_echo_plrm',
#   'dh0_l1b_echo_plrm',
#   'dop_cor_c_l1b_echo_plrm',
#   'dop_cor_ku_l1b_echo_plrm',
#   'flag_gnss_status_l1b_echo_plrm',
#   'flag_man_plane_l1b_echo_plrm',
#   'flag_man_pres_l1b_echo_plrm',
#   'flag_man_thrust_l1b_echo_plrm',
#   'flag_time_corr_val_l1b_echo_plrm',
#   'flag_time_status_l1b_echo_plrm',
#   'h0_applied_l1b_echo_plrm',
#   'h0_nav_dem_l1b_echo_plrm',
#   'int_path_cor_c_l1b_echo_plrm',
#   'int_path_cor_ku_l1b_echo_plrm',
#   'isp_coarse_time_l1b_echo_plrm',
#   'isp_fine_time_l1b_echo_plrm',
#   'isp_time_status_l1b_echo_plrm',
#   'lat_l1b_echo_plrm',
#   'lon_l1b_echo_plrm',
#   'loss_track_l1b_echo_plrm',
#   'nav_bul_coarse_time_l1b_echo_plrm',
#   'nav_bul_fine_time_l1b_echo_plrm',
#   'nav_bul_source_l1b_echo_plrm',
#   'nav_bul_status_l1b_echo_plrm',
#   'oper_instr_l1b_echo_plrm',
#   'orb_alt_rate_l1b_echo_plrm',
#   'range_c_l1b_echo_plrm',
#   'range_ku_l1b_echo_plrm',
#   'range_rate_l1b_echo_plrm',
#   'scale_factor_c_l1b_echo_plrm',
#   'scale_factor_ku_l1b_echo_plrm',
#   'seq_count_l1b_echo_plrm',
#   'sig0_cal_c_l1b_echo_plrm',
#   'sig0_cal_ku_l1b_echo_plrm',
#   'sral_fine_time_l1b_echo_plrm',
#   'surf_type_l1b_echo_plrm',
#   'time_l1b_echo_plrm',
#   'uso_cor_l1b_echo_plrm',
#   'weighting_l1b_echo_plrm',
#   'x_pos_l1b_echo_plrm',
#   'x_vel_l1b_echo_plrm',
#   'y_pos_l1b_echo_plrm',
#   'y_vel_l1b_echo_plrm',
#   'z_pos_l1b_echo_plrm',
#   'z_vel_l1b_echo_plrm'},
#  ('time_l1b_echo_plrm', 'echo_sample_ind'): {'i2q2_meas_c_l1b_echo_plrm',
#   'i2q2_meas_ku_l1b_echo_plrm'},
#  ('time_l1b_echo_sar_ku',): {'GPS_time_l1b_echo_sar_ku',
#   'SAR_mode_l1b_echo_sar_ku',
#   'UTC_day_l1b_echo_sar_ku',
#   'UTC_sec_l1b_echo_sar_ku',
#   'acq_stat_l1b_echo_sar_ku',
#   'agc_cor_ku_l1b_echo_sar_ku',
#   'agc_ku_l1b_echo_sar_ku',
#   'agccode_ku_l1b_echo_sar_ku',
#   'alt_l1b_echo_sar_ku',
#   'beam_form_l1b_echo_sar_ku',
#   'cl_gain_l1b_echo_sar_ku',
#   'cor2_applied_l1b_echo_sar_ku',
#   'cor2_nav_dem_l1b_echo_sar_ku',
#   'dem_eeprom_l1b_echo_sar_ku',
#   'dh0_l1b_echo_sar_ku',
#   'flag_gnss_status_l1b_echo_sar_ku',
#   'flag_man_plane_l1b_echo_sar_ku',
#   'flag_man_pres_l1b_echo_sar_ku',
#   'flag_man_thrust_l1b_echo_sar_ku',
#   'flag_time_corr_val_l1b_echo_sar_ku',
#   'flag_time_status_l1b_echo_sar_ku',
#   'h0_applied_l1b_echo_sar_ku',
#   'h0_nav_dem_l1b_echo_sar_ku',
#   'int_path_cor_ku_l1b_echo_sar_ku',
#   'isp_coarse_time_l1b_echo_sar_ku',
#   'isp_fine_time_l1b_echo_sar_ku',
#   'isp_time_status_l1b_echo_sar_ku',
#   'kurt_stack_l1b_echo_sar_ku',
#   'lat_l1b_echo_sar_ku',
#   'lon_l1b_echo_sar_ku',
#   'loss_track_l1b_echo_sar_ku',
#   'max_stack_l1b_echo_sar_ku',
#   'nav_bul_coarse_time_l1b_echo_sar_ku',
#   'nav_bul_fine_time_l1b_echo_sar_ku',
#   'nav_bul_source_l1b_echo_sar_ku',
#   'nav_bul_status_l1b_echo_sar_ku',
#   'nb_stack_l1b_echo_sar_ku',
#   'oper_instr_l1b_echo_sar_ku',
#   'orb_alt_rate_l1b_echo_sar_ku',
#   'range_ku_l1b_echo_sar_ku',
#   'range_rate_l1b_echo_sar_ku',
#   'scale_factor_ku_l1b_echo_sar_ku',
#   'seq_count_l1b_echo_sar_ku',
#   'sig0_cal_ku_l1b_echo_sar_ku',
#   'skew_stack_l1b_echo_sar_ku',
#   'sral_fine_time_l1b_echo_sar_ku',
#   'stdev_stack_l1b_echo_sar_ku',
#   'surf_type_l1b_echo_sar_ku',
#   'time_l1b_echo_sar_ku',
#   'uso_cor_l1b_echo_sar_ku',
#   'weighting_l1b_echo_sar_ku',
#   'x_pos_l1b_echo_sar_ku',
#   'x_vel_l1b_echo_sar_ku',
#   'y_pos_l1b_echo_sar_ku',
#   'y_vel_l1b_echo_sar_ku',
#   'z_pos_l1b_echo_sar_ku',
#   'z_vel_l1b_echo_sar_ku'},
#  ('time_l1b_echo_sar_ku', 'echo_sample_ind'): {'i2q2_meas_ku_l1b_echo_sar_ku'},
#  ('time_l1b_echo_sar_ku',
#   'max_multi_stack_ind'): {'beam_ang_stack_l1b_echo_sar_ku'}}

# %%
an.dim_name_to_size
# Out:
# {'echo_sample_ind': 128,
#  'max_multi_stack_ind': 300,
#  'time_l1b_echo_lrm': 0,
#  'time_l1b_echo_plrm': 982,
#  'time_l1b_echo_sar_ku': 1021}

# %%
an.ds.dimensions.keys()
# Out:
# odict_keys(['echo_sample_ind', 'max_multi_stack_ind', 'time_l1b_echo_lrm', 'time_l1b_echo_sar_ku', 'time_l1b_echo_plrm'])

# %%
v = an.ds['scale_factor_ku_l1b_echo_lrm']

# %%
v.dimensions
# Out:
# ('time_l1b_echo_lrm',)
