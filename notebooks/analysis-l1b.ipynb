# %% [markdown]
# # DeDop L1B Analysis
#
# Use the following plot methods for displaying scaled waveform data:
# * `plot.waveform()` - to draw simple waveform line plots
# * `plot.waveform_im()` - to draw a waveform image
# * `plot.waveform_hist()` to draw waveform histograms
#
# Use the following methods for displaying any other variables:
# * `plot.line(x, y)` - to draw two 1D variables (line plots)
# * `plot.im_line(z)` - to draw a 2D variable (images + and line plots)
# * `plot.im(z)` - to draw a 2D variable (images)

# %%
from dedop.ui.analysis import inspect_l1b
# %matplotlib inline

# %%
insp = inspect_l1b("D:/EOData/DeDop/L1B.nc")
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2b8743f4-023f-4a87-b7b6-2c8693a1bcb5">Loading BokehJS ...</span>
#     </div>

# %%
insp.lon_range
# Out:
# (63.214408999999989, 63.872471999999988)

# %%
insp.lat_range
# Out:
# (3.97925, 6.9323030000000001)

# %%
insp.plot.locations()
# Out:
# [(7110251.058747624, 443324.61900037777), (7110179.3689955529, 443647.77987347014), (7110107.7905629762, 443970.94188364077), (7110036.2121303929, 444294.10503172327), (7109964.5223783217, 444617.26931855117), (7109892.9439457394, 444940.32315448811), (7109821.3655131627, 445263.48972091131), (7109749.7870805794, 445586.65742858069), (7109678.0973285083, 445909.82627832884), (7109606.5188959315, 446232.88467894634), (7109534.9404633492, 446556.05581495923), (7109463.2507112781, 446879.22809555021), (7109391.6722786948, 447202.28992832598), (7109320.0938461181, 447525.46450018336), (7109248.4040940469, 447848.75181314588), (7109176.8256614702, 448171.8170859752), (7109105.135909399, 448494.99510157795), (7109033.5574768158, 448818.28586197674), (7108961.8677247446, 449141.46617797582), (7108890.2892921623, 449464.64764522365), (7108818.7108595856, 449787.8302645568), (7108747.0211075144, 450111.01403680746), (7108675.4426749377, 450434.19896281161), (7108603.8642423544, 450757.38504339964), (7108532.1744902832, 451080.46068140632), (7108460.5960577009, 451403.64907326968), (7108388.9063056298, 451726.83862222056), (7108317.327873053, 452050.02932909242), (7108245.7494404754, 452373.10959511774), (7108174.0596884042, 452696.30261993367), (7108102.4812558219, 453019.49680517276), (7108030.9028232396, 453342.69215167017), (7107959.2130711684, 453665.77705905138), (7107887.6346385907, 453989.08633176947), (7107815.9448865205, 454312.17356503219), (7107744.3664539428, 454635.37356449565), (7107672.6767018717, 454958.68633220019), (7107601.0982692894, 455281.77706053737), (7107529.4085172182, 455604.9805587845), (7107457.8300846359, 455928.29682898376), (7107386.1403325647, 456251.39105990238), (7107314.561899987, 456574.59806444042), (7107242.9834674103, 456897.80623940949), (7107171.2937153336, 457221.01558564621), (7107099.7152827568, 457544.11449794), (7107028.0255306857, 457867.32618880691), (7106956.4470981024, 458190.53905344161), (7106884.7573460322, 458513.75309268106), (7106813.1789134545, 458836.85669968906), (7106741.6004808778, 459160.07309023029), (7106669.910728801, 459483.29065787647), (7106598.3322962243, 459806.50940346351), (7106526.6425441531, 460129.72932782443), (7106455.0641115699, 460452.95043179195), (7106383.3743594987, 460776.17271620536), (7106311.795926922, 461099.39618189418), (7106240.1061748508, 461422.62082969607), (7106168.5277422685, 461745.73504911002), (7106096.8379901974, 462068.96206322982), (7106025.2595576206, 462392.19026196306), (7105953.5698055495, 462715.41964614764), (7105881.9913729662, 463038.53860364493), (7105810.301620895, 463361.77036082017), (7105738.7231883183, 463685.00330594589), (7105667.0334362471, 464008.12582566019), (7105595.4550036648, 464331.36114878574), (7105523.7652515993, 464654.59766236681), (7105452.1868190169, 464977.83536723681), (7105380.4970669458, 465300.96264838724), (7105308.9186343625, 465624.31435419008), (7105237.2288822914, 465947.55563794059), (7105165.6504497146, 466270.68649923551), (7105093.9606976435, 466594.0417901614), (7105022.2709455723, 466917.28666030167), (7104950.69251299, 467240.42110925022), (7104879.0027609188, 467563.66837407782), (7104807.4243283421, 467886.916837706), (7104735.7345762709, 468210.05488140584), (7104664.1561436877, 468533.30574472703), (7104592.4663916221, 468856.55780935404), (7104520.8879590342, 469179.81107612263), (7104449.1982069686, 469502.9539246413), (7104377.6197743863, 469826.20959777839), (7104305.9300223207, 470149.4664755608), (7104234.2402702495, 470472.72455882217), (7104162.6618376672, 470795.98384839989), (7104090.9720855961, 471119.24434512563), (7104019.3936530128, 471442.50604983489), (7103947.7039009416, 471765.76896336424), (7103876.0141488705, 472089.03308654763), (7103804.4357162938, 472412.18679523887), (7103732.7459642226, 472735.45333981601), (7103661.1675316403, 473058.72109655122), (7103589.4777795691, 473381.99006628117), (7103517.7880275035, 473705.14862318395), (7103446.2095949212, 474028.4 ...
#     <div class="bk-root">
#         <div class="plotdiv" id="07f92a99-18bd-4d4e-924a-fad35e8f4f85"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("07f92a99-18bd-4d4e-924a-fad35e8f4f85");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '07f92a99-18bd-4d4e-924a-fad35e8f4f85' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"66c52a13-6a1b-4671-b2c5-fc80bd6b0938":{"roots":{"references":[{"attributes":{"plot":null,"text":"L1B Footprint"},"id":"c6696971-b53f-41f4-bf2f-13012180c3b9","type":"Title"},{"attributes":{},"id":"1bdc8a0f-ca6c-4909-96b1-ea2a027872d6","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e01ce738-2b27-4623-918c-52ba406d3323","type":"PanTool"},{"id":"e2e5a705-6fa7-4d38-933b-82dd50f83992","type":"WheelZoomTool"}]},"id":"7226f75c-ac2a-41bf-ba92-3d0ec03d084e","type":"Toolbar"},{"attributes":{"below":[{"id":"5b854f2d-83d6-4d3e-bf6d-fefb461ba1ab","type":"LinearAxis"}],"left":[{"id":"738fbd3b-8727-48c3-a788-ae3665822410","type":"LinearAxis"}],"renderers":[{"id":"5b854f2d-83d6-4d3e-bf6d-fefb461ba1ab","type":"LinearAxis"},{"id":"96d328e1-4ba4-4efa-a7dd-59c27d4a35b3","type":"Grid"},{"id":"738fbd3b-8727-48c3-a788-ae3665822410","type":"LinearAxis"},{"id":"24ee4917-77e2-4e65-990d-f2d6d956c5f7","type":"Grid"},{"id":"104564d9-21f6-4194-bf00-c2f7ab4aecb3","type":"TileRenderer"},{"id":"cd5e0623-c5c1-45cc-aeec-649c93e5cdf2","type":"TileRenderer"},{"id":"c90aba0a-ef7b-41d3-b19d-1105890ff3d4","type":"GlyphRenderer"}],"title":{"id":"c6696971-b53f-41f4-bf2f-13012180c3b9","type":"Title"},"tool_events":{"id":"af83ce48-e26f-4b8c-9c07-31fa0d5df7af","type":"ToolEvents"},"toolbar":{"id":"7226f75c-ac2a-41bf-ba92-3d0ec03d084e","type":"Toolbar"},"x_range":{"id":"017b76ac-046e-4782-881b-da382300c6c9","type":"Range1d"},"y_range":{"id":"1b1660fa-3fd5-490e-ae8d-5a3116e964e8","type":"Range1d"}},"id":"e4ffb3b1-20f9-4fa6-b611-f25f25f33628","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"e4ffb3b1-20f9-4fa6-b611-f25f25f33628","subtype":"Figure","type":"Plot"}},"id":"e2e5a705-6fa7-4d38-933b-82dd50f83992","type":"WheelZoomTool"},{"attributes":{"attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>.Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>","url":"http://tile.stamen.com/toner/{Z}/{X}/{Y}.png"},"id":"e3b638c6-55ec-4c16-8edb-a1c3d720f866","type":"WMTSTileSource"},{"attributes":{"callback":null,"end":7110251.058747624,"start":7036995.820677728},"id":"017b76ac-046e-4782-881b-da382300c6c9","type":"Range1d"},{"attributes":{},"id":"af83ce48-e26f-4b8c-9c07-31fa0d5df7af","type":"ToolEvents"},{"attributes":{"data_source":{"id":"61e1f216-968d-455f-87b0-6a68996e6485","type":"ColumnDataSource"},"glyph":{"id":"eefc9a86-3a9c-436a-a59c-4ba003f5c545","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c90aba0a-ef7b-41d3-b19d-1105890ff3d4","type":"GlyphRenderer"},{"attributes":{},"id":"bd9b9c2b-290e-4931-9989-69c0cf4b50d5","type":"BasicTicker"},{"attributes":{"attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://creativecommons.org/licenses/by-sa/3.0\">CC BY SA</a>.","url":"http://tile.stamen.com/terrain/{Z}/{X}/{Y}.png"},"id":"97fa83a5-6a92-499a-b73a-a760efe057dc","type":"WMTSTileSource"},{"attributes":{"plot":{"id":"e4ffb3b1-20f9-4fa6-b611-f25f25f33628","subtype":"Figure","type":"Plot"},"ticker":{"id":"bd9b9c2b-290e-4931-9989-69c0cf4b50d5","type":"BasicTicker"}},"id":"96d328e1-4ba4-4efa-a7dd-59c27d4a35b3","type":"Grid"},{"attributes":{},"id":"fe90f8e9-d203-4bc2-89fe-5695e2f996bc","type":"BasicTickFormatter"},{"attributes":{},"id":"1d80a06d-d018-460f-87ac-e77c2613c506","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"fe90f8e9-d203-4bc2-89fe-5695e2f996bc","type":"BasicTickFormatter"},"plot":{"id":"e4ffb3b1-20f9-4fa6-b611-f25f25f33628","subtype":"Figure","type":"Plot"},"ticker":{"id":"1bdc8a0f-ca6c-4909-96b1-ea2a027872d6","type":"BasicTicker"}},"id":"738fbd3b-8727-4 ...

# %%
insp.waveform_range
# Out:
# (1205.3677999999998, 30087273.237540003)

# %%
insp.waveform
# Out:
# array([[ 451718.3201 ,  391009.53948,  469832.19884, ...,  207594.06872,
#           36962.92574,   34729.03718],
#        [ 484006.6816 ,  372133.504  ,  412135.8592 , ...,  206755.84   ,
#           52053.3504 ,   49204.864  ],
#        [ 117785.5893 ,  130503.6735 ,  137601.465  , ...,   18778.8531 ,
#           16616.5008 ,   11575.0674 ],
#        ...,
#        [  86142.71736,   93009.71632,   89435.07616, ...,  101436.4852 ,
#           65133.03776,   30685.63616],
#        [  79221.38692,   93830.11248,   76573.4424 , ...,   32368.20652,
#           47028.53012,   38394.13292],
#        [  97763.66815,   81546.629  ,   96229.2843 , ...,   44382.1326 ,
#           28040.2804 ,   13342.44845]])

# %%
insp.plot.waveform_im(vmin=0, vmax=7e6)

# %%
insp.plot.waveform_hist(vmin=0, vmax=1e7, log=True)

# %%
insp.plot.waveform(ind=500)

# %%
insp.plot.waveform()

# %%
insp.plot.waveform(ref_ind=520)

# %%
insp.plot.line()

# %%
insp.plot.line(x='lon_l1b_echo_sar_ku', y='lat_l1b_echo_sar_ku')

# %%
insp.plot.im()

# %%
insp.plot.im_line()

# %%
insp.dim_names
# Out:
# ['echo_sample_ind',
#  'max_multi_stack_ind',
#  'time_l1b_echo_lrm',
#  'time_l1b_echo_plrm',
#  'time_l1b_echo_sar_ku']

# %%
insp.var_names
# Out:
# ['GPS_time_l1b_echo_lrm',
#  'GPS_time_l1b_echo_plrm',
#  'GPS_time_l1b_echo_sar_ku',
#  'SAR_mode_l1b_echo_plrm',
#  'SAR_mode_l1b_echo_sar_ku',
#  'UTC_day_l1b_echo_lrm',
#  'UTC_day_l1b_echo_plrm',
#  'UTC_day_l1b_echo_sar_ku',
#  'UTC_sec_l1b_echo_lrm',
#  'UTC_sec_l1b_echo_plrm',
#  'UTC_sec_l1b_echo_sar_ku',
#  'acq_stat_l1b_echo_lrm',
#  'acq_stat_l1b_echo_plrm',
#  'acq_stat_l1b_echo_sar_ku',
#  'agc_c_l1b_echo_lrm',
#  'agc_c_l1b_echo_plrm',
#  'agc_cor_c_l1b_echo_lrm',
#  'agc_cor_c_l1b_echo_plrm',
#  'agc_cor_ku_l1b_echo_lrm',
#  'agc_cor_ku_l1b_echo_plrm',
#  'agc_cor_ku_l1b_echo_sar_ku',
#  'agc_ku_l1b_echo_lrm',
#  'agc_ku_l1b_echo_plrm',
#  'agc_ku_l1b_echo_sar_ku',
#  'agccode_c_l1b_echo_lrm',
#  'agccode_c_l1b_echo_plrm',
#  'agccode_ku_l1b_echo_lrm',
#  'agccode_ku_l1b_echo_plrm',
#  'agccode_ku_l1b_echo_sar_ku',
#  'alt_l1b_echo_lrm',
#  'alt_l1b_echo_plrm',
#  'alt_l1b_echo_sar_ku',
#  'beam_ang_stack_l1b_echo_sar_ku',
#  'beam_form_l1b_echo_sar_ku',
#  'cl_gain_l1b_echo_lrm',
#  'cl_gain_l1b_echo_plrm',
#  'cl_gain_l1b_echo_sar_ku',
#  'cor2_applied_l1b_echo_lrm',
#  'cor2_applied_l1b_echo_plrm',
#  'cor2_applied_l1b_echo_sar_ku',
#  'cor2_nav_dem_l1b_echo_lrm',
#  'cor2_nav_dem_l1b_echo_plrm',
#  'cor2_nav_dem_l1b_echo_sar_ku',
#  'dem_eeprom_l1b_echo_lrm',
#  'dem_eeprom_l1b_echo_plrm',
#  'dem_eeprom_l1b_echo_sar_ku',
#  'dh0_l1b_echo_lrm',
#  'dh0_l1b_echo_plrm',
#  'dh0_l1b_echo_sar_ku',
#  'dop_cor_c_l1b_echo_lrm',
#  'dop_cor_c_l1b_echo_plrm',
#  'dop_cor_ku_l1b_echo_lrm',
#  'dop_cor_ku_l1b_echo_plrm',
#  'echo_sample_ind',
#  'flag_gnss_status_l1b_echo_lrm',
#  'flag_gnss_status_l1b_echo_plrm',
#  'flag_gnss_status_l1b_echo_sar_ku',
#  'flag_man_plane_l1b_echo_lrm',
#  'flag_man_plane_l1b_echo_plrm',
#  'flag_man_plane_l1b_echo_sar_ku',
#  'flag_man_pres_l1b_echo_lrm',
#  'flag_man_pres_l1b_echo_plrm',
#  'flag_man_pres_l1b_echo_sar_ku',
#  'flag_man_thrust_l1b_echo_lrm',
#  'flag_man_thrust_l1b_echo_plrm',
#  'flag_man_thrust_l1b_echo_sar_ku',
#  'flag_time_corr_val_l1b_echo_lrm',
#  'flag_time_corr_val_l1b_echo_plrm',
#  'flag_time_corr_val_l1b_echo_sar_ku',
#  'flag_time_status_l1b_echo_lrm',
#  'flag_time_status_l1b_echo_plrm',
#  'flag_time_status_l1b_echo_sar_ku',
#  'h0_applied_l1b_echo_lrm',
#  'h0_applied_l1b_echo_plrm',
#  'h0_applied_l1b_echo_sar_ku',
#  'h0_nav_dem_l1b_echo_lrm',
#  'h0_nav_dem_l1b_echo_plrm',
#  'h0_nav_dem_l1b_echo_sar_ku',
#  'i2q2_meas_c_l1b_echo_lrm',
#  'i2q2_meas_c_l1b_echo_plrm',
#  'i2q2_meas_ku_l1b_echo_lrm',
#  'i2q2_meas_ku_l1b_echo_plrm',
#  'i2q2_meas_ku_l1b_echo_sar_ku',
#  'int_path_cor_c_l1b_echo_lrm',
#  'int_path_cor_c_l1b_echo_plrm',
#  'int_path_cor_ku_l1b_echo_lrm',
#  'int_path_cor_ku_l1b_echo_plrm',
#  'int_path_cor_ku_l1b_echo_sar_ku',
#  'isp_coarse_time_l1b_echo_lrm',
#  'isp_coarse_time_l1b_echo_plrm',
#  'isp_coarse_time_l1b_echo_sar_ku',
#  'isp_fine_time_l1b_echo_lrm',
#  'isp_fine_time_l1b_echo_plrm',
#  'isp_fine_time_l1b_echo_sar_ku',
#  'isp_time_status_l1b_echo_lrm',
#  'isp_time_status_l1b_echo_plrm',
#  'isp_time_status_l1b_echo_sar_ku',
#  'kurt_stack_l1b_echo_sar_ku',
#  'lat_l1b_echo_lrm',
#  'lat_l1b_echo_plrm',
#  'lat_l1b_echo_sar_ku',
#  'lon_l1b_echo_lrm',
#  'lon_l1b_echo_plrm',
#  'lon_l1b_echo_sar_ku',
#  'loss_track_l1b_echo_lrm',
#  'loss_track_l1b_echo_plrm',
#  'loss_track_l1b_echo_sar_ku',
#  'max_multi_stack_ind',
#  'max_stack_l1b_echo_sar_ku',
#  'mode_id_l1b_echo_lrm',
#  'nav_bul_coarse_time_l1b_echo_lrm',
#  'nav_bul_coarse_time_l1b_echo_plrm',
#  'nav_bul_coarse_time_l1b_echo_sar_ku',
#  'nav_bul_fine_time_l1b_echo_lrm',
#  'nav_bul_fine_time_l1b_echo_plrm',
#  'nav_bul_fine_time_l1b_echo_sar_ku',
#  'nav_bul_source_l1b_echo_lrm',
#  'nav_bul_source_l1b_echo_plrm',
#  'nav_bul_source_l1b_echo_sar_ku',
#  'nav_bul_status_l1b_echo_lrm',
#  'nav_bul_status_l1b_echo_plrm',
#  'nav_bul_status_l1b_echo_sar_ku',
#  'nb_stack_l1b_echo_sar_ku',
#  'oper_instr_l1b_echo_lrm',
#  'oper_instr_l1b_echo_plrm',
#  'oper_instr_l1b_echo_sar_ku',
#  'orb_alt_rate_l1b_echo_lrm',
#  'orb_alt_rate_l1b_echo_plrm',
#  'orb_alt_rate_l1b_echo_sar_ku',
#  'range_c_l1b_echo_lrm',
#  'range_c_l1b_echo_plrm',
#  'range_ku_l1b_echo_lrm',
#  'range_ku_l1b_echo_plrm',
#  'range_ku_l1b_echo_sar_ku',
#  'range_rate_l1b_echo_lrm',
#  'range_rate_l1b_echo_plrm',
#  'range_rate_l1b_echo_sar_ku',
#  'scale_factor_c_l1b_echo_lrm',
#  'scale_factor_c_l1b_echo_plrm',
#  'scale_factor_ku_l1b_echo_lrm',
#  'scale_factor_ku_l1b_echo_plrm',
#  'scale_factor_ku_l1b_echo_sar_ku',
#  'seq_count_l1b_echo_lrm',
#  'seq_count_l1b_echo_plrm',
#  'seq_count_l1b_echo_sar_ku',
#  'sig0_cal_c_l1b_echo_lrm',
#  'sig0_cal_c_l1b_echo_plrm',
#  'sig0_cal_ku_l1b_echo_lrm',
#  'sig0_cal_ku_l1b_echo_plrm',
#  'sig0_cal_ku_l1b_echo_sar_ku',
#  'skew_stack_l1b_echo_sar_ku',
#  'sral_fine_time_l1b_echo_lrm',
#  'sral_fine_time_l1b_echo_plrm',
#  'sral_fine_time_l1b_echo_sar_ku',
#  'stdev_stack_l1b_echo_sar_ku',
#  'surf_type_l1b_echo_lrm',
#  'surf_type_l1b_echo_plrm',
#  'surf_type_l1b_echo_sar_ku',
#  'time_l1b_echo_lrm',
#  'time_l1b_echo_plrm',
#  'time_l1b_echo_sar_ku',
#  'uso_cor_l1b_echo_lrm',
#  'uso_cor_l1b_echo_plrm',
#  'uso_cor_l1b_echo_sar_ku',
#  'weighting_l1b_echo_lrm',
#  'weighting_l1b_echo_plrm',
#  'weighting_l1b_echo_sar_ku',
#  'x_pos_l1b_echo_lrm',
#  'x_pos_l1b_echo_plrm',
#  'x_pos_l1b_echo_sar_ku',
#  'x_vel_l1b_echo_lrm',
#  'x_vel_l1b_echo_plrm',
#  'x_vel_l1b_echo_sar_ku',
#  'y_pos_l1b_echo_lrm',
#  'y_pos_l1b_echo_plrm',
#  'y_pos_l1b_echo_sar_ku',
#  'y_vel_l1b_echo_lrm',
#  'y_vel_l1b_echo_plrm',
#  'y_vel_l1b_echo_sar_ku',
#  'z_pos_l1b_echo_lrm',
#  'z_pos_l1b_echo_plrm',
#  'z_pos_l1b_echo_sar_ku',
#  'z_vel_l1b_echo_lrm',
#  'z_vel_l1b_echo_plrm',
#  'z_vel_l1b_echo_sar_ku']

# %%
insp.dim_name_to_size
# Out:
# {'echo_sample_ind': 128,
#  'max_multi_stack_ind': 300,
#  'time_l1b_echo_lrm': 0,
#  'time_l1b_echo_plrm': 982,
#  'time_l1b_echo_sar_ku': 1021}

# %%
insp.dim_names_to_var_names
# Out:
# {('echo_sample_ind',): {'echo_sample_ind'},
#  ('max_multi_stack_ind',): {'max_multi_stack_ind'},
#  ('time_l1b_echo_lrm',): {'GPS_time_l1b_echo_lrm',
#   'UTC_day_l1b_echo_lrm',
#   'UTC_sec_l1b_echo_lrm',
#   'acq_stat_l1b_echo_lrm',
#   'agc_c_l1b_echo_lrm',
#   'agc_cor_c_l1b_echo_lrm',
#   'agc_cor_ku_l1b_echo_lrm',
#   'agc_ku_l1b_echo_lrm',
#   'agccode_c_l1b_echo_lrm',
#   'agccode_ku_l1b_echo_lrm',
#   'alt_l1b_echo_lrm',
#   'cl_gain_l1b_echo_lrm',
#   'cor2_applied_l1b_echo_lrm',
#   'cor2_nav_dem_l1b_echo_lrm',
#   'dem_eeprom_l1b_echo_lrm',
#   'dh0_l1b_echo_lrm',
#   'dop_cor_c_l1b_echo_lrm',
#   'dop_cor_ku_l1b_echo_lrm',
#   'flag_gnss_status_l1b_echo_lrm',
#   'flag_man_plane_l1b_echo_lrm',
#   'flag_man_pres_l1b_echo_lrm',
#   'flag_man_thrust_l1b_echo_lrm',
#   'flag_time_corr_val_l1b_echo_lrm',
#   'flag_time_status_l1b_echo_lrm',
#   'h0_applied_l1b_echo_lrm',
#   'h0_nav_dem_l1b_echo_lrm',
#   'int_path_cor_c_l1b_echo_lrm',
#   'int_path_cor_ku_l1b_echo_lrm',
#   'isp_coarse_time_l1b_echo_lrm',
#   'isp_fine_time_l1b_echo_lrm',
#   'isp_time_status_l1b_echo_lrm',
#   'lat_l1b_echo_lrm',
#   'lon_l1b_echo_lrm',
#   'loss_track_l1b_echo_lrm',
#   'mode_id_l1b_echo_lrm',
#   'nav_bul_coarse_time_l1b_echo_lrm',
#   'nav_bul_fine_time_l1b_echo_lrm',
#   'nav_bul_source_l1b_echo_lrm',
#   'nav_bul_status_l1b_echo_lrm',
#   'oper_instr_l1b_echo_lrm',
#   'orb_alt_rate_l1b_echo_lrm',
#   'range_c_l1b_echo_lrm',
#   'range_ku_l1b_echo_lrm',
#   'range_rate_l1b_echo_lrm',
#   'scale_factor_c_l1b_echo_lrm',
#   'scale_factor_ku_l1b_echo_lrm',
#   'seq_count_l1b_echo_lrm',
#   'sig0_cal_c_l1b_echo_lrm',
#   'sig0_cal_ku_l1b_echo_lrm',
#   'sral_fine_time_l1b_echo_lrm',
#   'surf_type_l1b_echo_lrm',
#   'time_l1b_echo_lrm',
#   'uso_cor_l1b_echo_lrm',
#   'weighting_l1b_echo_lrm',
#   'x_pos_l1b_echo_lrm',
#   'x_vel_l1b_echo_lrm',
#   'y_pos_l1b_echo_lrm',
#   'y_vel_l1b_echo_lrm',
#   'z_pos_l1b_echo_lrm',
#   'z_vel_l1b_echo_lrm'},
#  ('time_l1b_echo_lrm', 'echo_sample_ind'): {'i2q2_meas_c_l1b_echo_lrm',
#   'i2q2_meas_ku_l1b_echo_lrm'},
#  ('time_l1b_echo_plrm',): {'GPS_time_l1b_echo_plrm',
#   'SAR_mode_l1b_echo_plrm',
#   'UTC_day_l1b_echo_plrm',
#   'UTC_sec_l1b_echo_plrm',
#   'acq_stat_l1b_echo_plrm',
#   'agc_c_l1b_echo_plrm',
#   'agc_cor_c_l1b_echo_plrm',
#   'agc_cor_ku_l1b_echo_plrm',
#   'agc_ku_l1b_echo_plrm',
#   'agccode_c_l1b_echo_plrm',
#   'agccode_ku_l1b_echo_plrm',
#   'alt_l1b_echo_plrm',
#   'cl_gain_l1b_echo_plrm',
#   'cor2_applied_l1b_echo_plrm',
#   'cor2_nav_dem_l1b_echo_plrm',
#   'dem_eeprom_l1b_echo_plrm',
#   'dh0_l1b_echo_plrm',
#   'dop_cor_c_l1b_echo_plrm',
#   'dop_cor_ku_l1b_echo_plrm',
#   'flag_gnss_status_l1b_echo_plrm',
#   'flag_man_plane_l1b_echo_plrm',
#   'flag_man_pres_l1b_echo_plrm',
#   'flag_man_thrust_l1b_echo_plrm',
#   'flag_time_corr_val_l1b_echo_plrm',
#   'flag_time_status_l1b_echo_plrm',
#   'h0_applied_l1b_echo_plrm',
#   'h0_nav_dem_l1b_echo_plrm',
#   'int_path_cor_c_l1b_echo_plrm',
#   'int_path_cor_ku_l1b_echo_plrm',
#   'isp_coarse_time_l1b_echo_plrm',
#   'isp_fine_time_l1b_echo_plrm',
#   'isp_time_status_l1b_echo_plrm',
#   'lat_l1b_echo_plrm',
#   'lon_l1b_echo_plrm',
#   'loss_track_l1b_echo_plrm',
#   'nav_bul_coarse_time_l1b_echo_plrm',
#   'nav_bul_fine_time_l1b_echo_plrm',
#   'nav_bul_source_l1b_echo_plrm',
#   'nav_bul_status_l1b_echo_plrm',
#   'oper_instr_l1b_echo_plrm',
#   'orb_alt_rate_l1b_echo_plrm',
#   'range_c_l1b_echo_plrm',
#   'range_ku_l1b_echo_plrm',
#   'range_rate_l1b_echo_plrm',
#   'scale_factor_c_l1b_echo_plrm',
#   'scale_factor_ku_l1b_echo_plrm',
#   'seq_count_l1b_echo_plrm',
#   'sig0_cal_c_l1b_echo_plrm',
#   'sig0_cal_ku_l1b_echo_plrm',
#   'sral_fine_time_l1b_echo_plrm',
#   'surf_type_l1b_echo_plrm',
#   'time_l1b_echo_plrm',
#   'uso_cor_l1b_echo_plrm',
#   'weighting_l1b_echo_plrm',
#   'x_pos_l1b_echo_plrm',
#   'x_vel_l1b_echo_plrm',
#   'y_pos_l1b_echo_plrm',
#   'y_vel_l1b_echo_plrm',
#   'z_pos_l1b_echo_plrm',
#   'z_vel_l1b_echo_plrm'},
#  ('time_l1b_echo_plrm', 'echo_sample_ind'): {'i2q2_meas_c_l1b_echo_plrm',
#   'i2q2_meas_ku_l1b_echo_plrm'},
#  ('time_l1b_echo_sar_ku',): {'GPS_time_l1b_echo_sar_ku',
#   'SAR_mode_l1b_echo_sar_ku',
#   'UTC_day_l1b_echo_sar_ku',
#   'UTC_sec_l1b_echo_sar_ku',
#   'acq_stat_l1b_echo_sar_ku',
#   'agc_cor_ku_l1b_echo_sar_ku',
#   'agc_ku_l1b_echo_sar_ku',
#   'agccode_ku_l1b_echo_sar_ku',
#   'alt_l1b_echo_sar_ku',
#   'beam_form_l1b_echo_sar_ku',
#   'cl_gain_l1b_echo_sar_ku',
#   'cor2_applied_l1b_echo_sar_ku',
#   'cor2_nav_dem_l1b_echo_sar_ku',
#   'dem_eeprom_l1b_echo_sar_ku',
#   'dh0_l1b_echo_sar_ku',
#   'flag_gnss_status_l1b_echo_sar_ku',
#   'flag_man_plane_l1b_echo_sar_ku',
#   'flag_man_pres_l1b_echo_sar_ku',
#   'flag_man_thrust_l1b_echo_sar_ku',
#   'flag_time_corr_val_l1b_echo_sar_ku',
#   'flag_time_status_l1b_echo_sar_ku',
#   'h0_applied_l1b_echo_sar_ku',
#   'h0_nav_dem_l1b_echo_sar_ku',
#   'int_path_cor_ku_l1b_echo_sar_ku',
#   'isp_coarse_time_l1b_echo_sar_ku',
#   'isp_fine_time_l1b_echo_sar_ku',
#   'isp_time_status_l1b_echo_sar_ku',
#   'kurt_stack_l1b_echo_sar_ku',
#   'lat_l1b_echo_sar_ku',
#   'lon_l1b_echo_sar_ku',
#   'loss_track_l1b_echo_sar_ku',
#   'max_stack_l1b_echo_sar_ku',
#   'nav_bul_coarse_time_l1b_echo_sar_ku',
#   'nav_bul_fine_time_l1b_echo_sar_ku',
#   'nav_bul_source_l1b_echo_sar_ku',
#   'nav_bul_status_l1b_echo_sar_ku',
#   'nb_stack_l1b_echo_sar_ku',
#   'oper_instr_l1b_echo_sar_ku',
#   'orb_alt_rate_l1b_echo_sar_ku',
#   'range_ku_l1b_echo_sar_ku',
#   'range_rate_l1b_echo_sar_ku',
#   'scale_factor_ku_l1b_echo_sar_ku',
#   'seq_count_l1b_echo_sar_ku',
#   'sig0_cal_ku_l1b_echo_sar_ku',
#   'skew_stack_l1b_echo_sar_ku',
#   'sral_fine_time_l1b_echo_sar_ku',
#   'stdev_stack_l1b_echo_sar_ku',
#   'surf_type_l1b_echo_sar_ku',
#   'time_l1b_echo_sar_ku',
#   'uso_cor_l1b_echo_sar_ku',
#   'weighting_l1b_echo_sar_ku',
#   'x_pos_l1b_echo_sar_ku',
#   'x_vel_l1b_echo_sar_ku',
#   'y_pos_l1b_echo_sar_ku',
#   'y_vel_l1b_echo_sar_ku',
#   'z_pos_l1b_echo_sar_ku',
#   'z_vel_l1b_echo_sar_ku'},
#  ('time_l1b_echo_sar_ku', 'echo_sample_ind'): {'i2q2_meas_ku_l1b_echo_sar_ku'},
#  ('time_l1b_echo_sar_ku',
#   'max_multi_stack_ind'): {'beam_ang_stack_l1b_echo_sar_ku'}}

# %%
var = insp.dataset['scale_factor_ku_l1b_echo_plrm']

# %%
var.name, var.dtype, var.dimensions, var.shape
# Out:
# ('scale_factor_ku_l1b_echo_plrm',
#  dtype('int32'),
#  ('time_l1b_echo_plrm',),
#  (982,))

# %%
insp.dataset
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Conventions: CF-1.6
#     title: IPF SRAL Level 1 Measurement
#     mission_name: Sentinel 3A
#     altimeter_sensor_name: SRAL
#     gnss_sensor_name: GNSS
#     doris_sensor_name: DORIS
#     netcdf_version: 4.2 of Jul  5 2012 17:07:43 $
#     product_name: S3A_SR_1_SRA____20130415T054207_20130415T054257_20160426T132200_0050_006_219______LN3_O_ST_456.SEN3
#     institution: LN3
#     source: IPF-SR-1 06.00.00
#     history:
#     references: S3IPF PDS 003 - i2r1 - Product Data Format Specification - SRAL-MWR
#     contact: EOHElp@esa.int
#     creation_time: 2016-04-26T13:22:02Z
#     acq_station_name: KIRUNA
#     first_meas_time: 2013-04-15T05:42:07.196557Z
#     last_meas_time: 2013-04-15T05:42:57.206901Z
#     xref_altimeter_level0: S3A_SR_0_SRA____20130415T054207_20130415T054257_20130123T160000_______________________________.SEN3
#     xref_navatt_level0: S3A_TM_0_NAT____20130415T054207_20130415T054257_20130123T160000_______________________________.SEN3
#     xref_altimeter_orbit: S3A_SR___MDO_AX_20000101T000000_20991231T235959_20130123T160000_______________________________.SEN3
#     xref_doris_uso: S3A_SR_1_USO_AX_20000101T000000_20991231T235959_20130101T000000_______________________D_AL____.SEN3
#     xref_altimeter_ltm_lrm_cal1: S3A_SR_1_CA1LAX_20000101T000000_20991231T235959_20130123T160000___________________LN3_________.SEN3
#     xref_altimeter_ltm_sar_cal1: S3A_SR_1_CA1SAX_20000101T000000_20991231T235959_20151027T100000___________________LN3_________.SEN3
#     xref_altimeter_ltm_ku_cal2: S3A_SR_1_CA2KAX_20000101T000000_20991231T235959_20151027T100000___________________LN3_________.SEN3
#     xref_altimeter_ltm_c_cal2: S3A_SR_1_CA2CAX_20000101T000000_20991231T235959_20151027T100000___________________LN3_________.SEN3
#     xref_altimeter_characterisation: S3A_SR___CHDRAX_20000101T000000_20991231T235959_20151214T120000___________________MPC_O_AL_001.SEN3
#     semi_major_ellipsoid_axis: 6378137.0
#     ellipsoid_flattening: 0.00335281066475
#     dimensions(sizes): echo_sample_ind(128), max_multi_stack_ind(300), time_l1b_echo_lrm(0), time_l1b_echo_sar_ku(1021), time_l1b_echo_plrm(982)
#     variables(dimensions): int8 echo_sample_ind(echo_sample_ind), int16 max_multi_stack_ind(max_multi_stack_ind), float64 time_l1b_echo_lrm(time_l1b_echo_lrm), int16 UTC_day_l1b_echo_lrm(time_l1b_echo_lrm), float64 UTC_sec_l1b_echo_lrm(time_l1b_echo_lrm), float64 GPS_time_l1b_echo_lrm(time_l1b_echo_lrm), uint32 isp_coarse_time_l1b_echo_lrm(time_l1b_echo_lrm), int32 isp_fine_time_l1b_echo_lrm(time_l1b_echo_lrm), uint32 sral_fine_time_l1b_echo_lrm(time_l1b_echo_lrm), int32 lat_l1b_echo_lrm(time_l1b_echo_lrm), int32 lon_l1b_echo_lrm(time_l1b_echo_lrm), int32 alt_l1b_echo_lrm(time_l1b_echo_lrm), int16 orb_alt_rate_l1b_echo_lrm(time_l1b_echo_lrm), int8 flag_time_status_l1b_echo_lrm(time_l1b_echo_lrm), int8 flag_time_corr_val_l1b_echo_lrm(time_l1b_echo_lrm), int8 flag_man_pres_l1b_echo_lrm(time_l1b_echo_lrm), int8 flag_man_thrust_l1b_echo_lrm(time_l1b_echo_lrm), int8 flag_man_plane_l1b_echo_lrm(time_l1b_echo_lrm), int8 flag_gnss_status_l1b_echo_lrm(time_l1b_echo_lrm), float64 x_pos_l1b_echo_lrm(time_l1b_echo_lrm), float64 y_pos_l1b_echo_lrm(time_l1b_echo_lrm), float64 z_pos_l1b_echo_lrm(time_l1b_echo_lrm), float64 x_vel_l1b_echo_lrm(time_l1b_echo_lrm), float64 y_vel_l1b_echo_lrm(time_l1b_echo_lrm), float64 z_vel_l1b_echo_lrm(time_l1b_echo_lrm), int8 nav_bul_status_l1b_echo_lrm(time_l1b_echo_lrm), int8 nav_bul_source_l1b_echo_lrm(time_l1b_echo_lrm), uint32 nav_bul_coarse_time_l1b_echo_lrm(time_l1b_echo_lrm), uint32 nav_bul_fine_time_l1b_echo_lrm(time_l1b_echo_lrm), uint16 seq_count_l1b_echo_lrm(time_l1b_echo_lrm), int8 isp_time_status_l1b_echo_lrm(time_l1b_echo_lrm), int8 oper_instr_l1b_echo_lrm(time_l1b_echo_lrm), int8 mode_id_l1b_echo_lrm(time_l1b_echo_lrm), int8 cl_gain_l1b_echo_lrm(time_l1b_echo_lrm), int8 acq_stat_l1b_echo_lrm(time_l1b_echo_lrm), int8 dem_eeprom_l1b_echo_lrm(time_l1b_echo_lrm), int8 weighting_l1b_echo_lrm(time_l1b_echo_lrm), int8 loss_track_l1b_echo_lrm(time_l1b_echo_lrm), uint32 h0_nav_dem_l1b_echo_lrm(time_l1b_echo_lrm), uint32 h0_applied_l1b_echo_lrm(time_l1b_echo_lrm), int16 cor2_nav_dem_l1b_echo_lrm(time_l1b_echo_lrm), int16 cor2_applied_l1b_echo_lrm(time_l1b_echo_lrm), int32 dh0_l1b_echo_lrm(time_l1b_echo_lrm), int8 agccode_ku_l1b_echo_lrm(time_l1b_echo_lrm), int8 agccode_c_l1b_echo_lrm(time_l1b_echo_lrm), int8 surf_type_l1b_echo_lrm(time_l1b_echo_lrm), int32 range_ku_l1b_echo_lrm(time_l1b_echo_lrm), int32 range_c_l1b_echo_lrm(time_l1b_echo_lrm), int32 uso_cor_l1b_echo_lrm(time_l1b_echo_lrm), int32 int_path_cor_ku_l1b_echo_lrm(time_l1b_echo_lrm), int32 int_path_cor_c_l1b_echo_lrm(time_l1b_echo_lrm), int32 dop_cor_ku_l1b_echo_lrm(time_l1b_echo_lrm), int32 dop_cor_c_l1b_echo_lrm(time_l1b_echo_lrm), int32 range_rate_l1b_echo_lrm(time_l1b_echo_lrm), int32 agc_ku_l1b_echo_lrm(time_l1b_echo_lrm), int32 agc_c_l1b_echo_lrm(time_l1b_echo_lrm), int32 scale_factor_ku_l1b_echo_lrm(time_l1b_echo_lrm), int32 scale_factor_c_l1b_echo_lrm(time_l1b_echo_lrm), int32 agc_cor_ku_l1b_echo_lrm(time_l1b_echo_lrm), int32 agc_cor_c_l1b_echo_lrm(time_l1b_echo_lrm), int32 sig0_cal_ku_l1b_echo_lrm(time_l1b_echo_lrm), int32 sig0_cal_c_l1b_echo_lrm(time_l1b_echo_lrm), uint32 i2q2_meas_ku_l1b_echo_lrm(time_l1b_echo_lrm,echo_sample_ind), uint32 i2q2_meas_c_l1b_echo_lrm(time_l1b_echo_lrm,echo_sample_ind), float64 time_l1b_echo_sar_ku(time_l1b_echo_sar_k), int16 UTC_day_l1b_echo_sar_ku(time_l1b_echo_sar_k), float64 UTC_sec_l1b_echo_sar_ku(time_l1b_echo_sar_k), float64 GPS_time_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 isp_coarse_time_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 isp_fine_time_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 sral_fine_time_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 lat_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 lon_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 alt_l1b_echo_sar_ku(time_l1b_echo_sar_k), int16 orb_alt_rate_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 flag_time_status_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 flag_time_corr_val_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 flag_man_pres_l1b_echo_sar_ku ...
#     groups:
