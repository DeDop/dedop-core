# %% [markdown]
# # DeDop L1B Inspection
#
# Use the following plot methods for displaying scaled waveform data:
# * `insp.plot.waveform_3d_surf()` - to draw a waveform 3D surface plot
# * `insp.plot.waveform_3d_line()` - to draw a waveform 3D line plot
# * `insp.plot.waveform_3d_poly()` - to draw a waveform 3D polygon plot
# * `insp.plot.waveform_im()` - to draw a waveform image
# * `insp.plot.waveform_line()` - to draw a waveform 2D line plot
# * `insp.plot.waveform_hist()` to draw a waveform histogram
# * `insp.plot.locations()` - to draw the footprints of the L1B product on a map
#
# Use the following generic methods for displaying any other variables:
# * `insp.plot.line(x, y)` - to draw two 1D variables (line plots)
# * `insp.plot.im_line(z)` - to draw a 2D variable (images + and line plots)
# * `insp.plot.im(z)` - to draw a 2D variable (images)
#
# Usage hints:
# * In menu **Cell** select **Run All** to run all notebook *cells*
# * Place cursor over a any field or function in a cell and press **SHIFT** + **TAB** to display help on
#   that element.
# * Type `comp.` or `comp.plot.` then press **TAB** key to get a list of available
#   elements of the `comp` and `comp.plot` objects for auto-completion.
# * Some functions have a `color` argument. Please refer to the
#   [Matplotlib Colors API](http://matplotlib.org/api/colors_api.html) to learn how colors can be specified.
# * Some functions have a `cmap` argument, which names a colour map. Please refer to the
#   [Matplotlib Colormaps Reference](http://matplotlib.org/examples/color/colormaps_reference.html)
#   for possible names.

# %%
from dedop.ui.inspect import inspect_l1b_product
# %matplotlib inline

# %%
insp = inspect_l1b_product('C:\\Users\\dedop-user\\.dedop\\workspaces\\default\\configs\\default\\outputs\\L1B_CS_LTA__SIR1SAR_FR_20150331T034023_20150331T034235_C001.DBL_default.nc')

# %%
insp.lon_range
# Out:
# (302.60141999999996, 303.43766699999998)

# %%
insp.lat_range
# Out:
# (-4.9084079999999997, 3.1390119999999997)

# %%
insp.plot.locations()
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="fe135a25-d8d9-480f-8769-55dbd237a991"></div>
# </div>

# %%
insp.waveform_range
# Out:
# (20.688600000000001, 604393663.9586401)

# %%
insp.waveform
# Out:
# array([[  865.15088,   846.46111,   746.59211, ...,   143.24068,
#           123.98023,   152.94224],
#        [ 1150.77622,  1107.54721,   979.42955, ...,   215.4317 ,
#           182.6176 ,   228.12933],
#        [  964.16386,  1005.39549,   904.38513, ...,   594.9339 ,
#           452.54924,   340.83863],
#        ...,
#        [  663.31932,   678.30072,   861.0738 , ...,   279.36744,
#           217.44432,   236.56344],
#        [  765.4782 ,   912.4386 ,  1021.30344, ...,   726.66924,
#           319.46052,   476.97924],
#        [ 1085.0814 ,  1193.66088,  1196.22912, ...,   471.41472,
#           356.98536,   476.26584]])

# %%
insp.plot.waveform_im(vmin=0, vmax=7e6)

# %%
insp.plot.waveform_hist(vmin=0, vmax=1e7, log=True)

# %%
insp.plot.waveform_line(ind=500)

# %%
insp.plot.waveform_line()
# Out:
# interactive(children=(IntSlider(value=1499, description='ind', max=2998), Output()), _dom_classes=('widget-interact',))

# %%
insp.plot.waveform_line(ref_ind=520)
# Out:
# interactive(children=(IntSlider(value=1499, description='ind', max=2998), Output()), _dom_classes=('widget-interact',))

# %%
insp.plot.waveform_3d_surf()

# %%
insp.plot.line()
# Out:
# interactive(children=(Dropdown(description='X:', options=('index', 'GPS_time_l1b_echo_sar_ku', 'SAR_mode_l1b_echo_sar_ku', 'UTC_day_l1b_echo_sar_ku', 'UTC_sec_l1b_echo_sar_ku', 'acq_stat_l1b_echo_sar_ku', 'agc_cor_ku_l1b_echo_sar_ku', 'agc_ku_l1b_echo_sar_ku', 'agccode_ku_l1b_echo_sar_ku', 'alt_l1b_echo_sar_ku', 'beam_form_l1b_echo_sar_ku', 'cl_gain_l1b_echo_sar_ku', 'cor2_applied_l1b_echo_sar_ku', 'cor2_nav_dem_l1b_echo_sar_ku', 'dem_eeprom_l1b_echo_sar_ku', 'dh0_l1b_echo_sar_ku', 'flag_gnss_status_l1b_echo_sar_ku', 'flag_man_plane_l1b_echo_sar_ku', 'flag_man_pres_l1b_echo_sar_ku', 'flag_man_thrust_l1b_echo_sar_ku', 'flag_time_status_l1b_echo_sar_ku', 'h0_applied_l1b_echo_sar_ku', 'h0_nav_dem_l1b_echo_sar_ku', 'int_path_cor_ku_l1b_echo_sar_ku', 'isp_coarse_time_l1b_echo_sar_ku', 'isp_fine_time_l1b_echo_sar_ku', 'isp_time_status_echo_sar_ku', 'kurt_stack_l1b_echo_sar_ku', 'lat_l1b_echo_sar_ku', 'lon_l1b_echo_sar_ku', 'loss_track_l1b_echo_sar_ku', 'max_stack_l1b_echo_sar_ku', 'nav_bul_coarse_time_l1b_echo_sar_ku', 'nav_bul_fine_time_l1b_echo_sar_ku', 'nav_bul_source_l1b_echo_sar_ku', 'nav_bul_status_l1b_echo_sar_ku', 'nb_stack_l1b_echo_sar_ku', 'oper_instr_l1b_echo_sar_ku', 'orb_alt_rate_l1b_echo_sar_ku', 'range_ku_l1b_echo_sar_ku', 'range_rate_l1b_echo_sar_ku', 'scale_factor_ku_l1b_echo_sar_ku', 'seq_count_l1b_echo_sar_ku', 'sig0_cal_ku_l1b_echo_sar_ku', 'skew_stack_l1b_echo_sar_ku', 'sral_fine_time_l1b_echo_sar_ku', 'stdev_stack_l1b_echo_sar_ku', 'surf_type_l1b_echo_sar_ku', 'time_l1b_echo_sar_ku', 'time_time_corr_val_l1b_echo_sar_ku', 'uso_cor_l1b_echo_sar_ku', 'weighting_l1b_echo_sar_ku', 'x_pos_l1b_echo_sar_ku', 'x_vel_l1b_echo_sar_ku', 'y_pos_l1b_echo_sar_ku', 'y_vel_l1b_echo_sar_ku', 'z_pos_l1b_echo_sar_ku', 'z_vel_l1b_echo_sar_ku'), value='index'), Dropdown(description='Y:', options=('GPS_time_l1b_echo_sar_ku', 'SAR_mode_l1b_echo_sar_ku', 'UTC_day_l1b_echo_sar_ku', 'UTC_sec_l1b_echo_sar_ku', 'acq_stat_l1b_echo_sar_ku', 'agc_cor_ku_l1b_echo_sar_ku', 'agc_ku_l1b_echo_sar_ku', 'agccode_ku_l1b_echo_sar_ku', 'alt_l1b_echo_sar_ku', 'beam_form_l1b_echo_sar_ku', 'cl_gain_l1b_echo_sar_ku', 'cor2_applied_l1b_echo_sar_ku', 'cor2_nav_dem_l1b_echo_sar_ku', 'dem_eeprom_l1b_echo_sar_ku', 'dh0_l1b_echo_sar_ku', 'flag_gnss_status_l1b_echo_sar_ku', 'flag_man_plane_l1b_echo_sar_ku', 'flag_man_pres_l1b_echo_sar_ku', 'flag_man_thrust_l1b_echo_sar_ku', 'flag_time_status_l1b_echo_sar_ku', 'h0_applied_l1b_echo_sar_ku', 'h0_nav_dem_l1b_echo_sar_ku', 'int_path_cor_ku_l1b_echo_sar_ku', 'isp_coarse_time_l1b_echo_sar_ku', 'isp_fine_time_l1b_echo_sar_ku', 'isp_time_status_echo_sar_ku', 'kurt_stack_l1b_echo_sar_ku', 'lat_l1b_echo_sar_ku', 'lon_l1b_echo_sar_ku', 'loss_track_l1b_echo_sar_ku', 'max_stack_l1b_echo_sar_ku', 'nav_bul_coarse_time_l1b_echo_sar_ku', 'nav_bul_fine_time_l1b_echo_sar_ku', 'nav_bul_source_l1b_echo_sar_ku', 'nav_bul_status_l1b_echo_sar_ku', 'nb_stack_l1b_echo_sar_ku', 'oper_instr_l1b_echo_sar_ku', 'orb_alt_rate_l1b_echo_sar_ku', 'range_ku_l1b_echo_sar_ku', 'range_rate_l1b_echo_sar_ku', 'scale_factor_ku_l1b_echo_sar_ku', 'seq_count_l1b_echo_sar_ku', 'sig0_cal_ku_l1b_echo_sar_ku', 'skew_stack_l1b_echo_sar_ku', 'sral_fine_time_l1b_echo_sar_ku', 'stdev_stack_l1b_echo_sar_ku', 'surf_type_l1b_echo_sar_ku', 'time_l1b_echo_sar_ku', 'time_time_corr_val_l1b_echo_sar_ku', 'uso_cor_l1b_echo_sar_ku', 'weighting_l1b_echo_sar_ku', 'x_pos_l1b_echo_sar_ku', 'x_vel_l1b_echo_sar_ku', 'y_pos_l1b_echo_sar_ku', 'y_vel_l1b_echo_sar_ku', 'z_pos_l1b_echo_sar_ku', 'z_vel_l1b_echo_sar_ku'), value='GPS_time_l1b_echo_sar_ku'), Output()), _dom_classes=('widget-interact',))

# %%
insp.plot.line(x='lon_l1b_echo_sar_ku', y='lat_l1b_echo_sar_ku')

# %%
insp.plot.im()
# Out:
# interactive(children=(Dropdown(description='z_name', options=('beam_ang_l1b_echo_sar_ku', 'i2q2_meas_ku_l1b_echo_sar_ku'), value='beam_ang_l1b_echo_sar_ku'), Output()), _dom_classes=('widget-interact',))

# %%
insp.plot.im_line()
# Out:
# interactive(children=(Dropdown(description='Var:', options=('beam_ang_l1b_echo_sar_ku', 'i2q2_meas_ku_l1b_echo_sar_ku'), value='beam_ang_l1b_echo_sar_ku'), IntSlider(value=0, description='X:', max=10), IntSlider(value=0, description='Y:', max=10), Output()), _dom_classes=('widget-interact',))

# %%
insp.dim_names
# Out:
# ['echo_sample_ind', 'max_multi_stack_ind', 'time_l1b_echo_sar_ku']

# %%
insp.var_names
# Out:
# ['GPS_time_l1b_echo_sar_ku',
#  'SAR_mode_l1b_echo_sar_ku',
#  'UTC_day_l1b_echo_sar_ku',
#  'UTC_sec_l1b_echo_sar_ku',
#  'acq_stat_l1b_echo_sar_ku',
#  'agc_cor_ku_l1b_echo_sar_ku',
#  'agc_ku_l1b_echo_sar_ku',
#  'agccode_ku_l1b_echo_sar_ku',
#  'alt_l1b_echo_sar_ku',
#  'beam_ang_l1b_echo_sar_ku',
#  'beam_form_l1b_echo_sar_ku',
#  'cl_gain_l1b_echo_sar_ku',
#  'cor2_applied_l1b_echo_sar_ku',
#  'cor2_nav_dem_l1b_echo_sar_ku',
#  'dem_eeprom_l1b_echo_sar_ku',
#  'dh0_l1b_echo_sar_ku',
#  'flag_gnss_status_l1b_echo_sar_ku',
#  'flag_man_plane_l1b_echo_sar_ku',
#  'flag_man_pres_l1b_echo_sar_ku',
#  'flag_man_thrust_l1b_echo_sar_ku',
#  'flag_time_status_l1b_echo_sar_ku',
#  'h0_applied_l1b_echo_sar_ku',
#  'h0_nav_dem_l1b_echo_sar_ku',
#  'i2q2_meas_ku_l1b_echo_sar_ku',
#  'int_path_cor_ku_l1b_echo_sar_ku',
#  'isp_coarse_time_l1b_echo_sar_ku',
#  'isp_fine_time_l1b_echo_sar_ku',
#  'isp_time_status_echo_sar_ku',
#  'kurt_stack_l1b_echo_sar_ku',
#  'lat_l1b_echo_sar_ku',
#  'lon_l1b_echo_sar_ku',
#  'loss_track_l1b_echo_sar_ku',
#  'max_stack_l1b_echo_sar_ku',
#  'nav_bul_coarse_time_l1b_echo_sar_ku',
#  'nav_bul_fine_time_l1b_echo_sar_ku',
#  'nav_bul_source_l1b_echo_sar_ku',
#  'nav_bul_status_l1b_echo_sar_ku',
#  'nb_stack_l1b_echo_sar_ku',
#  'oper_instr_l1b_echo_sar_ku',
#  'orb_alt_rate_l1b_echo_sar_ku',
#  'range_ku_l1b_echo_sar_ku',
#  'range_rate_l1b_echo_sar_ku',
#  'scale_factor_ku_l1b_echo_sar_ku',
#  'seq_count_l1b_echo_sar_ku',
#  'sig0_cal_ku_l1b_echo_sar_ku',
#  'skew_stack_l1b_echo_sar_ku',
#  'sral_fine_time_l1b_echo_sar_ku',
#  'stdev_stack_l1b_echo_sar_ku',
#  'surf_type_l1b_echo_sar_ku',
#  'time_l1b_echo_sar_ku',
#  'time_time_corr_val_l1b_echo_sar_ku',
#  'uso_cor_l1b_echo_sar_ku',
#  'weighting_l1b_echo_sar_ku',
#  'x_pos_l1b_echo_sar_ku',
#  'x_vel_l1b_echo_sar_ku',
#  'y_pos_l1b_echo_sar_ku',
#  'y_vel_l1b_echo_sar_ku',
#  'z_pos_l1b_echo_sar_ku',
#  'z_vel_l1b_echo_sar_ku']

# %%
insp.dim_name_to_size
# Out:
# {'echo_sample_ind': 256,
#  'max_multi_stack_ind': 240,
#  'time_l1b_echo_sar_ku': 2999}

# %%
insp.dim_names_to_var_names
# Out:
# {('time_l1b_echo_sar_ku',): {'GPS_time_l1b_echo_sar_ku',
#   'SAR_mode_l1b_echo_sar_ku',
#   'UTC_day_l1b_echo_sar_ku',
#   'UTC_sec_l1b_echo_sar_ku',
#   'acq_stat_l1b_echo_sar_ku',
#   'agc_cor_ku_l1b_echo_sar_ku',
#   'agc_ku_l1b_echo_sar_ku',
#   'agccode_ku_l1b_echo_sar_ku',
#   'alt_l1b_echo_sar_ku',
#   'beam_form_l1b_echo_sar_ku',
#   'cl_gain_l1b_echo_sar_ku',
#   'cor2_applied_l1b_echo_sar_ku',
#   'cor2_nav_dem_l1b_echo_sar_ku',
#   'dem_eeprom_l1b_echo_sar_ku',
#   'dh0_l1b_echo_sar_ku',
#   'flag_gnss_status_l1b_echo_sar_ku',
#   'flag_man_plane_l1b_echo_sar_ku',
#   'flag_man_pres_l1b_echo_sar_ku',
#   'flag_man_thrust_l1b_echo_sar_ku',
#   'flag_time_status_l1b_echo_sar_ku',
#   'h0_applied_l1b_echo_sar_ku',
#   'h0_nav_dem_l1b_echo_sar_ku',
#   'int_path_cor_ku_l1b_echo_sar_ku',
#   'isp_coarse_time_l1b_echo_sar_ku',
#   'isp_fine_time_l1b_echo_sar_ku',
#   'isp_time_status_echo_sar_ku',
#   'kurt_stack_l1b_echo_sar_ku',
#   'lat_l1b_echo_sar_ku',
#   'lon_l1b_echo_sar_ku',
#   'loss_track_l1b_echo_sar_ku',
#   'max_stack_l1b_echo_sar_ku',
#   'nav_bul_coarse_time_l1b_echo_sar_ku',
#   'nav_bul_fine_time_l1b_echo_sar_ku',
#   'nav_bul_source_l1b_echo_sar_ku',
#   'nav_bul_status_l1b_echo_sar_ku',
#   'nb_stack_l1b_echo_sar_ku',
#   'oper_instr_l1b_echo_sar_ku',
#   'orb_alt_rate_l1b_echo_sar_ku',
#   'range_ku_l1b_echo_sar_ku',
#   'range_rate_l1b_echo_sar_ku',
#   'scale_factor_ku_l1b_echo_sar_ku',
#   'seq_count_l1b_echo_sar_ku',
#   'sig0_cal_ku_l1b_echo_sar_ku',
#   'skew_stack_l1b_echo_sar_ku',
#   'sral_fine_time_l1b_echo_sar_ku',
#   'stdev_stack_l1b_echo_sar_ku',
#   'surf_type_l1b_echo_sar_ku',
#   'time_l1b_echo_sar_ku',
#   'time_time_corr_val_l1b_echo_sar_ku',
#   'uso_cor_l1b_echo_sar_ku',
#   'weighting_l1b_echo_sar_ku',
#   'x_pos_l1b_echo_sar_ku',
#   'x_vel_l1b_echo_sar_ku',
#   'y_pos_l1b_echo_sar_ku',
#   'y_vel_l1b_echo_sar_ku',
#   'z_pos_l1b_echo_sar_ku',
#   'z_vel_l1b_echo_sar_ku'},
#  ('time_l1b_echo_sar_ku', 'echo_sample_ind'): {'i2q2_meas_ku_l1b_echo_sar_ku'},
#  ('time_l1b_echo_sar_ku', 'max_multi_stack_ind'): {'beam_ang_l1b_echo_sar_ku'}}

# %%
var = insp.dataset['i2q2_meas_ku_l1b_echo_sar_ku']

# %%
var.name, var.dtype, var.dimensions, var.shape
# Out:
# ('i2q2_meas_ku_l1b_echo_sar_ku',
#  dtype('uint32'),
#  ('time_l1b_echo_sar_ku', 'echo_sample_ind'),
#  (2999, 256))

# %%
insp.dataset
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     software_name: dedop
#     software_version: 1.4.0.dev1
#     dimensions(sizes): time_l1b_echo_sar_ku(2999), echo_sample_ind(256), max_multi_stack_ind(240)
#     variables(dimensions): float64 time_l1b_echo_sar_ku(time_l1b_echo_sar_k), int16 UTC_day_l1b_echo_sar_ku(time_l1b_echo_sar_k), float64 UTC_sec_l1b_echo_sar_ku(time_l1b_echo_sar_k), float64 GPS_time_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 isp_coarse_time_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 isp_fine_time_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 sral_fine_time_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 lat_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 lon_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 alt_l1b_echo_sar_ku(time_l1b_echo_sar_k), int16 orb_alt_rate_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 flag_time_status_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 time_time_corr_val_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 flag_man_pres_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 flag_man_thrust_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 flag_man_plane_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 flag_gnss_status_l1b_echo_sar_ku(time_l1b_echo_sar_k), float64 x_pos_l1b_echo_sar_ku(time_l1b_echo_sar_k), float64 y_pos_l1b_echo_sar_ku(time_l1b_echo_sar_k), float64 z_pos_l1b_echo_sar_ku(time_l1b_echo_sar_k), float64 x_vel_l1b_echo_sar_ku(time_l1b_echo_sar_k), float64 y_vel_l1b_echo_sar_ku(time_l1b_echo_sar_k), float64 z_vel_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 nav_bul_status_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 nav_bul_source_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 nav_bul_coarse_time_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 nav_bul_fine_time_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint16 seq_count_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 isp_time_status_echo_sar_ku(time_l1b_echo_sar_k), int8 oper_instr_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 SAR_mode_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 cl_gain_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 acq_stat_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 dem_eeprom_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 weighting_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 loss_track_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 h0_nav_dem_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 h0_applied_l1b_echo_sar_ku(time_l1b_echo_sar_k), int16 cor2_nav_dem_l1b_echo_sar_ku(time_l1b_echo_sar_k), int16 cor2_applied_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 dh0_l1b_echo_sar_ku(time_l1b_echo_sar_k), int16 agccode_ku_l1b_echo_sar_ku(time_l1b_echo_sar_k), int8 surf_type_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 range_ku_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 uso_cor_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 int_path_cor_ku_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 range_rate_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 agc_ku_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 scale_factor_ku_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 agc_cor_ku_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 sig0_cal_ku_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint16 nb_stack_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 max_stack_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 stdev_stack_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 skew_stack_l1b_echo_sar_ku(time_l1b_echo_sar_k), int32 kurt_stack_l1b_echo_sar_ku(time_l1b_echo_sar_k), int16 beam_ang_l1b_echo_sar_ku(time_l1b_echo_sar_k,max_multi_stack_ind), uint16 beam_form_l1b_echo_sar_ku(time_l1b_echo_sar_k), uint32 i2q2_meas_ku_l1b_echo_sar_ku(time_l1b_echo_sar_k,echo_sample_ind)
#     groups:
